# %% [markdown]
# # Guidance for NetworkX

# %% [markdown]
# ## 1. Motivation
# NetworkX is a Python language software package to create and manipulate complex networks. NetworkX contains useful functions for different kinds of networks.<br />
#
# With NetworkX you can load and store networks in standard and nonstandard data formats, generate many types of random and classic networks, analyze network structure, build network models, design new network algorithms, draw networks, and much more.

# %% [markdown]
# ## 2. Context (Similar Packages)
# The following packages can be used to visualize network, structure and relationship like NetworkX.<br />
#
# Graph-tool: <br />
# Graph-tool is an efficient Python module for manipulation and statistical analysis of graphs (a.k.a. networks). Contrary to most other python modules with similar functionality, the core data structures and algorithms are implemented in C++. So the algorithms run fast and running time is important when you deal with big dataset.<br />
#
# Python-igraph: <br />
# igraph is a collection of network analysis tools with the emphasis on efficiency, portability and ease of use. igraph is open source and free.<br />
#
# Plotly: <br />
# Plotly is the collaboration platform for agile business intelligence and modern data science. You can make simple and complicated graph either use Plotly online Graph Maker or use Python after installed this package.

# %% [markdown]
# ## 3. Installation instruction, platform restriction and dependent libraries
# Quick install: <br />
# pip install networkx<br />
# pip install git://github.com/networkx/networkx.git#egg=networkx (development version)<br />
#
# Requirement: <br />
# To use NetworkX you need Python 2.7, 3.2 or later.<br />
#
# Dependent libraries: <br />
# NetworkX’s main purpose is to enable graph analysis, but not graph visualization. As a result, it is much better to use a tool that mainly does graph visualization. Here are some easy and good examples of packages that can be used with NetworkX to perform graph visualization, such as: Matplotlib, AGraph, Pydot, Layout

# %% [markdown]
# ## 4. Minimal Working Example

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create an empty graph with no nodes and no edges.
G=nx.Graph()

print(G.nodes())
print(G.edges())

print(type(G.nodes()))
print(type(G.edges()))
# Out:
# []
# []
# <class 'list'>
# <class 'list'>

# %%
#Add nodes
G=nx.Graph()
# adding just one node:
G.add_node("a")
# a list of nodes:
G.add_nodes_from(["b","c"])

print("Nodes of graph: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
# Out:
# Nodes of graph:
# ['a', 'b', 'c']
# Edges of graph:
# []

# %%
#Add edges
G=nx.Graph()
G.add_node("a")
G.add_nodes_from(["b","c"])

G.add_edge(1,2)
edge = ("d", "e")
G.add_edge(*edge)
edge = ("a", "b")
G.add_edge(*edge)

print("Nodes of graph: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
# Out:
# Nodes of graph:
# ['a', 'b', 'c', 1, 2, 'd', 'e']
# Edges of graph:
# [('a', 'b'), (1, 2), ('d', 'e')]

# %%
G.add_edges_from([("a","c"),("c","d"), ("a",1), (1,"d"), ("a",2)])
nx.draw(G)
plt.savefig("simple_path.png") # save as png
plt.show() # display
# Out:
# /Users/francesfang/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/francesfang/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/francesfang/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
G=nx.path_graph(4)

print("Nodes of graph: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
nx.draw(G)
plt.savefig("path_graph1.png")
plt.show()
# Out:
# Nodes of graph:
# [0, 1, 2, 3]
# Edges of graph:
# [(0, 1), (1, 2), (2, 3)]
# /Users/francesfang/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/francesfang/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/francesfang/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %% [markdown]
# ## 5. Example of typical use-cases

# %% [markdown]
# ### Example 1: Simple Network(Relationship)
# This is a simple example of showing the network(relationship) between different fruits.<br />

# %%
import networkx as nx
import matplotlib.pyplot as plt

#Create an empty Graph called G
G=nx.Graph()

#add edges to graph G
G.add_edge('Apple', 'Mango') 
G.add_edge('Mango', 'Orange') 
G.add_edge('Grape', 'Banana') 
G.add_edge('Banana', 'Apple') 
G.add_edge('Orange', 'Plum') 
G.add_edge('Pinapple', 'Plum')
G.add_edge('Mango', 'Plum')
G.add_edge('Pinapple', 'Orange')

# add nodes to graph with color=red
G.add_nodes_from(['Apple', 'Banana','Orange','Grape','Mango', 'Pinapple','Plum'])

#We want the graph layouts to be shell shape
graph_shape = nx.shell_layout(G)

#we add blue nodes into graph G. node_color controls for the color of each node, and alpha controls the darkness of that color
nx.draw_networkx_nodes(G, graph_shape, node_size=800, node_color=['red','blue','yellow'], alpha=0.2)
plt.show()

# %%
#we add network edges into graph G
nx.draw_networkx_edges(G, graph_shape)
plt.show()

# %%
#we add labels to graph G, and you can adjust the font and its size.
nx.draw_networkx_labels(G, graph_shape, font_size=12, font_family='sans-serif')
plt.show()

# %%
#run the above 3 stes together and show the network about relationship between fruits.
nx.draw_networkx_nodes(G, graph_shape, node_size=1000, node_color=['red','blue','yellow'], alpha=0.3)
nx.draw_networkx_edges(G, graph_shape)
nx.draw_networkx_labels(G, graph_shape, font_size=10, font_family='sans-serif')

plt.show()

# %% [markdown]
# ### Example 2: Random Geometric Graph
# In graph theory, a random geometric graph (RGG) is the mathematically simplest spatial network, namely an undirected graph constructed by randomly placing N nodes in some metric space (according to a specified probability distribution) and connecting two nodes by a link if and only if their distance is in a given range, e.g. smaller than a certain neighborhood radius, r.<br />
# A real-world application of RGGs is the modeling of ad hoc networks.<br />

# %% [markdown]
# The random geometric graph model places n nodes uniformly at random in the unit cube. Two nodes are joined by an edge if the Euclidean distance between the nodes is at most radius.

# %% [markdown]
# With package networkx, you can make random geometric graph using the following function.<br />
# random_geometric_graph(n, radius, dim=2, pos=None)<br />
#
# Parameters:	<br />
# n (int) – Number of nodes<br />
# radius (float) – Distance threshold value<br />
# dim (int, optional) – Dimension of graph<br />
# pos (dict, optional) – A dictionary keyed by node with node positions as values.<br />

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.random_geometric_graph(300, 0.13)
# position is stored as node attribute data for random_geometric_graph
pos = nx.get_node_attributes(G, 'pos')

# find node near center (0.3, 0.2)
dmin = 1
ncenter = 0
for n in pos:
    x, y = pos[n]
    d = (x - 0.3)**2 + (y - 0.2)**2
    if d < dmin:
        ncenter = n
        dmin = d

# color by path length from node near center
p = nx.single_source_shortest_path_length(G, ncenter)

plt.figure(figsize = (8, 8))
nx.draw_networkx_edges(G, pos,nodelist = [ncenter], alpha = 0.3)
nx.draw_networkx_nodes(G, pos, nodelist = p.keys(),
                       node_size = 75,
                       node_color = list(p.values()),
                       cmap = plt.cm.PuRd_r)

plt.xlim(-0.05, 1.05)
plt.ylim(-0.05, 1.1)

font = {'fontname'   : 'fantasy',
        'color'      : 'k',
        'fontweight' : 'bold',
        'fontsize'   : 16}
plt.title("Random Geometric Graph", font)

plt.text(0.5, 0.97, "Number of nodes = 300",
         horizontalalignment = 'center',
         transform = plt.gca().transAxes)
plt.text(0.5, 0.94,  "Distance threshold value = 0.13",
         horizontalalignment = 'center',
         transform = plt.gca().transAxes)

    
plt.axis('off')
plt.savefig('random_geometric_graph.png')
plt.show()

# %% [markdown]
# ## 6. List other or useful features
#
# •	Python language data structures for graphs, digraphs, and multigraphs.<br />
#
# •	Many standard graph algorithms<br />
#
# •	Network structure and analysis measures<br />
#
# •	Generators for classic graphs, random graphs, and synthetic networks<br />
#
# •	Nodes can be "anything" (e.g. text, images, XML records)<br />
#
# •	Edges can hold arbitrary data (e.g. weights, time-series)<br />
#
# •	Open source BSD license<br />
#
# •	Well tested: more than 1800 unit tests, >90% code coverage<br />
#
# •	Additional benefits from Python: fast prototyping, easy to teach, multi-platform<br />

# %% [markdown]
# ## 7. Summary and personal assessment of the library
#
# Advantage of NetworkX:<br />
# NetworkX is really popular among researchers in different areas, such as biology, math, computer science, and social science. This package provide researchers a easy and comprehensive tool to graph the structure, dynamics, and relationships that they are interested to study.<br />
# NetworkX is easy to import through Python, by just using import networkx as nx ; the functions are mostly self-explanatory, and users can learn it really quickly.  For example, add_node() means to add a node to graph, number_of_nodes() checks number of nodes for each graph.
# NetworkX is really flexible in terms of that it allow graphs of graphs, graphs of files, graphs of functions.<br />
# In NetworkX, You can have different types of nodes in the parameter, as long as it is a hashable object (except None). Moreover, you can have arbitrary data for edges. You can also add different kinds of attributes to graphs, nodes, or edges, which makes the visual presentation really meaningful.<br />
# NetworkX works with both standard and non-standard datasets<br />
# NetworkX works with directed graphs and multigraphs<br />
# NetworkX is a open-source tool base, and users can use in multidisciplinary environment. This tool doesn’t require users to be expert in coding. <br />
#
# Issue associated:<br />
# NetworkX needs big memory storage<br />
# May run slower for large scale problems. <br />

# %% [markdown]
# ## 8. References:
# http://igraph.org/c/doc/<br />
# http://networkx.readthedocs.io/en/networkx-1.10/<br />
# https://graph-tool.skewed.de<br />
# https://plot.ly/python/<br />
# https://en.wikipedia.org/wiki/Random_geometric_graph<br />
# http://www.python-course.eu/networkx.php<br />
# http://stackoverflow.com/questions/20133479/how-to-draw-directed-graphs-using-networkx-in-python<br />
